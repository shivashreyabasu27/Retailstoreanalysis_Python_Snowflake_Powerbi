# %%
import pandas as pd

# %% [markdown]
# ### Importing raw data for EDA

# %%
new= pd.read_csv('https://raw.githubusercontent.com/TechCoachRepo/EndtoEndSalesProject/refs/heads/master/One%20Time%20Load/Fact%20Orders/factorders.csv')

# %% [markdown]
# ### Data Exploration

# %%
new.head(10)
# Out:
#      DateID  ProductID  StoreID  CustomerID  QuantityOrderded  OrderAmount  \
# 0  20170217        142       90         538                12          936
# 1  20221217        459       93         455                10          361
# 2  20190304        259       28         762                19          243
# 3  20231128        990       24         207                12          903
# 4  20181017        752       38         432                 5          322
# 5  20231202        845        3         939                11          186
# 6  20140413        626       10         366                11          444
# 7  20181230        637       53         989                10          811
# 8  20141224        208       79         224                14          210
# 9  20220602        724       20         609                 4          395
#
#    DiscountAmount  Shipping Cost  TotalAmount
# 0       75.187017     124.778228   736.034754
# 1       41.081798      30.328877   289.589325
# ...

# %%
new.tail(10)
# Out:
#           DateID  ProductID  StoreID  CustomerID  QuantityOrderded  \
# 999990  20180202        883       10         567                18
# 999991  20151106        636       50         909                 7
# 999992  20220215        423       96         347                17
# 999993  20140322        329       95         405                 9
# 999994  20200828        599       91         288                 1
# 999995  20141112        865       90          96                19
# 999996  20181223        202        6         689                16
# 999997  20190916        330       48         139                 1
# 999998  20180602        653       56         196                15
# 999999  20240615        850       86         623                 5
#
#         OrderAmount  DiscountAmount  Shipping Cost  TotalAmount
# 999990          579       29.676620      79.718555   469.604825
# 999991          447       47.521640      32.711324   366.767035
# ...

# %%
new.shape
# Out:
# (1000000, 9)

# %%
new.describe()
# Out:
#              DateID       ProductID         StoreID      CustomerID  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   2.018861e+07      500.600265       50.442834      500.512225
# std    3.053775e+04      288.697242       28.855470      288.797436
# min    2.014010e+07        1.000000        1.000000        1.000000
# 25%    2.016082e+07      250.000000       25.000000      250.000000
# 50%    2.019041e+07      501.000000       50.000000      501.000000
# 75%    2.021120e+07      751.000000       75.000000      751.000000
# max    2.024073e+07     1000.000000      100.000000     1000.000000
#
#        QuantityOrderded     OrderAmount  DiscountAmount   Shipping Cost  \
# count    1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean          10.492662      549.737436       46.706510       54.984709
# std            5.765948      260.141970       31.778225       31.396642
# ...

# %%
new.dtypes
# Out:
# DateID                int64
# ProductID             int64
# StoreID               int64
# CustomerID            int64
# QuantityOrderded      int64
# OrderAmount           int64
# DiscountAmount      float64
# Shipping Cost       float64
# TotalAmount         float64
# dtype: object

# %% [markdown]
# ### Data Transformations

# %%
new.head(10).isnull()
# Out:
#    DateID  ProductID  StoreID  CustomerID  QuantityOrderded  OrderAmount  \
# 0   False      False    False       False             False        False
# 1   False      False    False       False             False        False
# 2   False      False    False       False             False        False
# 3   False      False    False       False             False        False
# 4   False      False    False       False             False        False
# 5   False      False    False       False             False        False
# 6   False      False    False       False             False        False
# 7   False      False    False       False             False        False
# 8   False      False    False       False             False        False
# 9   False      False    False       False             False        False
#
#    DiscountAmount  Shipping Cost  TotalAmount
# 0           False          False        False
# 1           False          False        False
# ...

# %%
new.head(10).isnull().sum()
# Out:
# DateID              0
# ProductID           0
# StoreID             0
# CustomerID          0
# QuantityOrderded    0
# OrderAmount         0
# DiscountAmount      0
# Shipping Cost       0
# TotalAmount         0
# dtype: int64

# %%
new.fillna(0)
# Out:
#           DateID  ProductID  StoreID  CustomerID  QuantityOrderded  \
# 0       20170217        142       90         538                12
# 1       20221217        459       93         455                10
# 2       20190304        259       28         762                19
# 3       20231128        990       24         207                12
# 4       20181017        752       38         432                 5
# ...          ...        ...      ...         ...               ...
# 999995  20141112        865       90          96                19
# 999996  20181223        202        6         689                16
# 999997  20190916        330       48         139                 1
# 999998  20180602        653       56         196                15
# 999999  20240615        850       86         623                 5
#
#         OrderAmount  DiscountAmount  Shipping Cost  TotalAmount
# 0               936       75.187017     124.778228   736.034754
# ...

# %% [markdown]
# ### Exporting transformed data

# %%
data= new.head(100)

# %%
data.to_csv('Factdata.csv', index=False)

# %% [markdown]
# ### connecting with snowflake for Data Ingestion
